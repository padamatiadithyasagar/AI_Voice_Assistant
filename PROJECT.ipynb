# %%
from gtts import gTTS
import speech_recognition as sr
import os
import re
import wikipedia
import webbrowser
import requests
import time
#from weather import Weather

def talkToMe(audio):
    "speaks audio passed as argument"

    print(audio)
    for line in audio.splitlines():
        os.system("say " + audio)

    #  use the system's inbuilt say command instead of mpg123
    #  text_to_speech = gTTS(text=audio, lang='en')
    #  text_to_speech.save('audio.mp3')
    #  os.system('mpg123 audio.mp3')


def myCommand():
    "listens for commands"

    r = sr.Recognizer()

    with sr.Microphone() as source:
        print('Ready...')
        r.pause_threshold = 1
        r.adjust_for_ambient_noise(source, duration=1)
        audio = r.listen(source)

    try:
        command = r.recognize_google(audio).lower()
        print('You said: ' + command + '\n')

    #loop back to continue to listen for commands if unrecognizable speech is received
    except sr.UnknownValueError:
        print('Your last command couldn\'t be heard')
        command = myCommand();

    return command


def assistant(command):
    "if statements for executing commands"

    if 'open reddit' in command:
        reg_ex = re.search('open reddit (.*)', command)
        url = 'https://www.reddit.com/'
        if reg_ex:
            subreddit = reg_ex.group(1)
            url = url + 'r/' + subreddit
        webbrowser.open(url)
        print('Done!')

    elif 'open website' in command:
        reg_ex = re.search('open website (.+)', command)
        if reg_ex:
            domain = reg_ex.group(1)
            url = 'https://www.' + domain
            webbrowser.open(url)
            print('Done!')
        else:
            pass

    elif 'what are you doing' in command:
        talkToMe('Just doing my thing')
        
    elif 'the time' in command:
            strTime = datetime.datetime.now().strftime("% H:% M:% S")   
            talkToMe(f"Sir, the time is {strTime}")

    elif 'wikipedia' in command:
            talkToMe('Searching Wikipedia...')
            command = command.replace("wikipedia", "")
            results = wikipedia.summary(command, sentences = 3)
            talkToMe("According to Wikipedia")
            print(results)
            talkToMe(results)
            
    elif 'play music' in command or "play song" in command:
            talkToMe("Here you go with music")
            music_dir = "C:\\Users\\Adithya\\Desktop\\PPython\\Music"
            songs = os.listdir(music_dir)
            print(songs)   
            random = os.startfile(os.path.join(music_dir, songs[0]))
            
    elif 'tell me a joke' in command:
        res = requests.get(
                'https://icanhazdadjoke.com/',
                headers={"Accept":"application/json"}
                )
        if res.status_code == requests.codes.ok:
            talkToMe(str(res.json()['joke']))
        else:
            talkToMe('oops!I ran out of jokes')




talkToMe('I am ready for your command')

#loop to continue executing multiple commands
while True:
    assistant(myCommand())
# Out:
# I am ready for your command
# Ready...
# You said: open reddit
#
# Done!
# Ready...
# Your last command couldn't be heard
# Ready...
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# Input In [14], in myCommand()
#      36 try:
# ---> 37     command = r.recognize_google(audio).lower()
#      38     print('You said: ' + command + '\n')
#
# File ~\anaconda3\lib\site-packages\speech_recognition\__init__.py:728, in Recognizer.recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     726     return actual_result
# --> 728 if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     730 if "confidence" in actual_result["alternative"]:
#     731     # return alternative with highest confidence score
#
# UnknownValueError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [14], in <cell line: 138>()
#     136 #loop to continue executing multiple commands
#     137 while True:
# --> 138     assistant(myCommand())
#
# Input In [14], in myCommand()
#      41 except sr.UnknownValueError:
#      42     print('Your last command couldn\'t be heard')
# ---> 43     command = myCommand();
#      45 return command
#
# Input In [14], in myCommand()
#      32     r.pause_threshold = 1
#      33     r.adjust_for_ambient_noise(source, duration=1)
# ---> 34     audio = r.listen(source)
#      36 try:
#      37     command = r.recognize_google(audio).lower()
#
# File ~\anaconda3\lib\site-packages\speech_recognition\__init__.py:491, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     488 if timeout and elapsed_time > timeout:
#     489     raise WaitTimeoutError("listening timed out while waiting for phrase to start")
# --> 491 buffer = source.stream.read(source.CHUNK)
#     492 if len(buffer) == 0: break  # reached end of the stream
#     493 frames.append(buffer)
#
# File ~\anaconda3\lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~\anaconda3\lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
